# %%
import numpy as np
import math


isFinish = True
runtime=0
easy_finish = 0
easy_stucked = 0
while(runtime<100):
    boardsizex = 16
    boardsizey = 16
    mines = 25
    safe_cells = round(math.sqrt(boardsizex*boardsizey))
    # %run -i "/Users/hsiaochuhao/Downloads/AIprog3.py"
    if(isFinish == True):
        easy_finish+=1
    else:
        easy_stucked+=1
    runtime+=1
print("safe cells = round(sqrt(size)")
print("medium finish: ", end = '')
print(easy_finish)
print("medium stuck: ",end = '')
print(easy_stucked)

isFinish = True
runtime=0
easy_finish = 0
easy_stucked = 0
while(runtime<100):
    boardsizex = 16
    boardsizey = 16
    mines = 25
    safe_cells = 2*round(math.sqrt(boardsizex*boardsizey))
    # %run -i "/Users/hsiaochuhao/Downloads/AIprog3.py"
    if(isFinish == True):
        easy_finish+=1
    else:
        easy_stucked+=1
    runtime+=1
print("safe cells = 2*round(sqrt(size)")
print("medium finish: ", end = '')
print(easy_finish)
print("medium stuck: ",end = '')
print(easy_stucked)

isFinish = True
runtime=0
easy_finish = 0
easy_stucked = 0
while(runtime<100):
    boardsizex = 16
    boardsizey = 16
    mines = 25
    safe_cells = 3*round(math.sqrt(boardsizex*boardsizey))
    # %run -i "/Users/hsiaochuhao/Downloads/AIprog3.py"
    if(isFinish == True):
        easy_finish+=1
    else:
        easy_stucked+=1
    runtime+=1
print("safe cells = 3*round(sqrt(size)")
print("medium finish: ", end = '')
print(easy_finish)
print("medium stuck: ",end = '')
print(easy_stucked)

# runtime = 0
# medium_finish = 0
# medium_stucked = 0
# while(runtime<10):
#     boardsizex = 16
#     boardsizey = 16
#     mines = 25
#     %run -i "/Users/hsiaochuhao/Downloads/AIprog3.py"
#     if(isFinish == True):
#         medium_finish+=1
#     else:
#         medium_stucked+=1
#     runtime+=1
# data.append(medium_finish/10)
# data.append(medium_stucked/10)
    
# runtime = 0
# hard_finish = 0
# hard_stucked = 0
# while(runtime<20):
#     boardsizex = 30
#     boardsizey = 16
#     mines = 99
#     %run -i "/Users/hsiaochuhao/Downloads/AIprog3.py"
#     if(isFinish == True):
#         hard_finish+=1
#     else:
#         hard_stucked+=1
#     runtime+=1
# data.append(hard_finish/20)
# data.append(hard_stucked/20)
# Out:
# safe cells = round(sqrt(size)
# medium finish: 91
# medium stuck: 9
# safe cells = 2*round(sqrt(size)
# medium finish: 88
# medium stuck: 12
# safe cells = 3*round(sqrt(size)
# medium finish: 90
# medium stuck: 10

# %%
import numpy as np
import matplotlib.pyplot as plt
import time 

data = []
isFinish = True
# runtime=0
# spent_time = 0
# while(runtime<50):
#     boardsizex = 9
#     boardsizey = 9
#     mines = 10
#     start_time = time.time()
#     %run -i "/Users/hsiaochuhao/Downloads/AIprog3.py"
#     spent_time += time.time()-start_time
#     runtime+=1

    
runtime = 0
spent_time = 0
while(runtime<50):
    boardsizex = 16
    boardsizey = 16
    mines = 25
    start_time = time.time()
    # %run -i "/Users/hsiaochuhao/Downloads/AIprog3.py"
    spent_time += time.time()-start_time
    runtime+=1
data.append(spent_time/50)
    
# runtime = 0
# spent_time = 0
# while(runtime<20):
#     boardsizex = 30
#     boardsizey = 16
#     start_time = time.time()
#     %run -i "/Users/hsiaochuhao/Downloads/AIprog3.py"
#     spent_time += time.time()-start_time
#     runtime+=1
# data.append(spent_time/20)

print(spent_time/50)
# Out:
# 1.3812112283706666

# %%
# import time
# boardsizex = 9
# boardsizey = 9
# mines = 10
# spent_time = 0
# start_time = time.time()
# %run -i "/Users/hsiaochuhao/Downloads/AIprog3.py"
# spent_time += time.time()-start_time
# print(spent_time)
